# %% [markdown]
# # Image to Pencil Sketch with Python
# ## 1. Run the cells of  filter.ipynb file
# ## 2. Deploy the Streamlit based webapp in the LocalHost using the command (streamlit run app.py)

# %% [markdown]
# ## Importing Libraries

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### Image

# %%
img= cv2.imread("IMAGES/image1.png")

# %% [markdown]
# ### Display the image using the Library OpenCV

# %%
cv2.imshow("Original Image",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Displaying Using Matpltotlib Library

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# ### Convert BGR to RGB

# %%
RBG_img= cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(RBG_img)
plt.show()

# %% [markdown]
# ### Convert into Grey Image

# %%
GREY_img= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %% [markdown]
# ### Inverting the Image

# %%
INVERT_img= cv2.bitwise_not(GREY_img)

# %% [markdown]
# ### Blur Image and Invert it

# %%
BLUR_img= cv2.GaussianBlur(INVERT_img,(111,111),0)
REQUIRED_img= cv2.bitwise_not(INVERT_img)

# %% [markdown]
# ### Sketch ( Bit-wise divison between inverted-image and gray-scale image)

# %%
SKETCH_img= cv2.divide(GREY_img,INVERT_img,scale=256.0)

# %%
cv2.imshow("SKETCH",SKETCH_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imsave("sketch_image.png",SKETCH_img)
